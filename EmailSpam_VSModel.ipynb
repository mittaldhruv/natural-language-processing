# %%
import re
import numpy as np
import pandas as pd
from sklearn import svm
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from sklearn.feature_extraction.text import CountVectorizer

f = open("Email_spam.txt")
lines = []
for l in f.readlines():
  lines.append(l.rsplit("\t"))
f.close()
lines = np.array(lines)

target = lines[:, 0]
text = lines[:, 1]

# %%
text
# Out:
# array([ 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...\n',
#        'Ok lar... Joking wif u oni...\n',
#        "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's\n",
#        ..., 'Pity, * was in mood for that. So...any other suggestions?\n',
#        "The guy did some bitching but I acted like i'd be interested in buying something else next week and he gave it to us for free\n",
#        'Rofl. Its true to its name\n'],
#       dtype='<U911')

# %%
stops = set(stopwords.words('english'))

def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
lemmatizer = WordNetLemmatizer()

def clean_data(data):
    meaningful_words = []
                    
    for w in data:   
        if w.lower() not in stops:
            pos = pos_tag([w])
            n_word = lemmatizer.lemmatize(w, pos = get_simple_pos(pos[0][1]))
            meaningful_words.append(n_word)
            
    return (" ".join(meaningful_words))

clean_text = []
for i in range(text.size):
    temp_text = re.sub('[^A-Za-z0-9 ]+', '', text[i])
    clean_text.append(clean_data(word_tokenize(temp_text)))

# %%
clean_text
# Out:
# ['Go jurong point crazy Available bugis n great world la e buffet Cine get amore wat',
#  'Ok lar Joking wif u oni',
#  'Free entry 2 wkly comp win FA Cup final tkts 21st May 2005 Text FA 87121 receive entry questionstd txt rateTCs apply 08452810075over18s',
#  'U dun say early hor U c already say',
#  'Nah dont think go usf life around though',
#  'FreeMsg Hey darling 3 week word back Id like fun still Tb ok XxX std chgs send 150 rcv',
#  'Even brother like speak treat like aid patent',
#  'per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friend Callertune',
#  'WINNER value network customer select receivea 900 prize reward claim call 09061701461 Claim code KL341 Valid 12 hour',
#  'mobile 11 month U R entitle Update late colour mobile camera Free Call Mobile Update Co FREE 08002986030',
#  'Im gon na home soon dont want talk stuff anymore tonight k Ive cry enough today',
#  'SIX chance win CASH 100 20000 pound txt CSH11 send 87575 Cost 150pday 6days 16 TsandCs apply Reply HL 4 info',
#  'URGENT 1 week FREE membership 100000 Prize Jackpot Txt word CLAIM 81010 TC wwwdbuknet LCCLTD POBOX 4403LDNW1A7RW18',
#  'Ive search right word thank breather promise wont take help grant fulfil promise wonderful blessing time',
#  'DATE SUNDAY',
#  'XXXMobileMovieClub use credit click WAP link next txt message click httpwap xxxmobilemovieclubcomnQJKGIGHJJGCBL',
#  'Oh kim watch',
#  'Eh u remember 2 spell name Yes v naughty make v wet',
#  'Fine thats way u feel Thats way gota b',
#  'England v Macedonia dont miss goalsteam news Txt ur national team 87077 eg ENGLAND 87077 TryWALES SCOTLAND 4txt120 POBOXox36504W45WQ 16',
#  'seriously spell name',
#  'Im go try 2 month ha ha joking',
#  'pay first lar da stock comin',
#  'Aft finish lunch go str lor Ard 3 smth lor U finish ur lunch already',
#  'Ffffffffff Alright way meet sooner',
#  'force eat slice Im really hungry tho suck Mark get worried know Im sick turn pizza Lol',
#  'Lol always convincing',
#  'catch bus fry egg make tea eat mom left dinner feel Love',
#  'Im back amp pack car Ill let know there room',
#  'Ahhh Work vaguely remember feel like Lol',
#  'Wait thats still clear sure sarcastic thats x doesnt want live u',
#  'Yeah get 2 v apologetic n fall actin like spoilt child get caught Till 2 wont go badly cheer',
#  'K tell anything',
#  'fear fainting housework Quick cuppa',
#  'Thanks subscription Ringtone UK mobile charge 5month Please confirm reply YES reply charge',
#  'Yup Ok go home look timing msg Xuhui go learn 2nd may lesson 8am',
#  'Oops Ill let know roommate do',
#  'see letter B car',
#  'Anything lor U decide',
#  'Hello Hows saturday go texting see youd decide anything tomo im try invite anything',
#  'Pls go ahead watt want sure great weekend Abiola',
#  'forget tell want need crave love sweet Arabian steed Mmmmmm Yummy',
#  '07732584351 Rodger Burns MSG try call reply sm free nokia mobile free camcorder Please call 08000930705 delivery tomorrow',
#  'SEEING',
#  'Great hope like man well endow ltgt inch',
#  'callsmessagesmissed call',
#  'Didnt get hep b immunisation nigeria',
#  'Fair enough anything go',
#  'Yeah hopefully tyler cant could maybe ask around bit',
#  'U dont know stubborn didnt even want go hospital kept tell Mark Im weak sucker Hospitals weak sucker',
#  'thinked First time saw class',
#  'gram usually run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'K fyi x ride early tomorrow morning he crash place tonight',
#  'Wow never realize embarassed accomodations thought like since best could always seem happy cave Im sorry didnt dont give Im sorry offer Im sorry room embarassing',
#  'SMS ac Sptv New Jersey Devils Detroit Red Wings play Ice Hockey Correct Incorrect End Reply END SPTV',
#  'know Mallika Sherawat yesterday Find ltURLgt',
#  'Congrats 1 year special cinema pas 2 call 09061209465 C Suprman V Matrix3 StarWars3 etc 4 FREE bx420ip45we 150pm Dont miss',
#  'Sorry Ill call later meeting',
#  'Tell reach',
#  'Yesgauti sehwag odi series',
#  'gon na pick 1 burger way home cant even move Pain kill',
#  'Ha ha ha good joke Girls situation seeker',
#  'part check IQ',
#  'Sorry roommate take forever ok come',
#  'Ok lar double check wif da hair dresser already say wun cut v short say cut look nice',
#  'value customer pleased advise follow recent review Mob award 1500 Bonus Prize call 09066364589',
#  'Today song dedicate day song u dedicate Send ur valuable frnds first rply',
#  'Urgent UR award complimentary trip EuroDisinc Trav AcoEntry41 1000 claim txt DIS 87121 186150moreFrmMob ShrAcomOrSglSuplt10 LS1 3AJ',
#  'hear new Divorce Barbie come Kens stuff',
#  'plane give month end',
#  'Wah lucky man save money Hee',
#  'Finished class',
#  'HI BABE IM HOME WAN NA SOMETHING XX',
#  'Kkwhere youhow perform',
#  'U call',
#  'wait machan Call free',
#  'Thats cool gentleman treat dignity respect',
#  'like people much shy pa',
#  'operate ltgt',
#  'Still look job much Tas earn',
#  'Sorry Ill call later',
#  'K call ah',
#  'Ok way home hi hi',
#  'place man',
#  'Yup next stop',
#  'call later dont network urgnt sm',
#  'real u get yo need 2 ticket one jacket Im do already use multis',
#  'Yes start send request make pain come back Im back bed Double coin factory get ta cash nitros',
#  'Im really still tonight babe',
#  'Ela kanoil download come wen ur free',
#  'Yeah Dont stand close tho youll catch something',
#  'Sorry pain ok meet another night spent late afternoon casualty mean havent do stuff42moro include time sheet Sorry',
#  'Smile Pleasure Smile Pain Smile trouble pours like Rain Smile sum1 Hurts U Smile becoz SOMEONE still Loves see u Smiling',
#  'Please call customer service representative 0800 169 6031 10am9pm guaranteed 1000 cash 5000 prize',
#  'Havent planning buy later check already lido get 530 show e afternoon U finish work already',
#  'free ringtone wait collect Simply text password MIX 85069 verify Get Usher Britney FML PO Box 5249 MK17 92H 450Ppw 16',
#  'Watching telugu moviewat abt u',
#  'see finish load loan pay',
#  'Hi Wk ok hols Yes bit run Forgot hairdresser appointment four need get home n shower beforehand cause prob u',
#  'see cup coffee animation',
#  'Please dont text anymore nothing else say',
#  'Okay name ur price long legal Wen pick u ave x am xx',
#  'Im still look car buy go 4the drive test yet',
#  'per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friend Callertune',
#  'wow Youre right didnt mean guess give boston men change search location nyc something change Cuz signin page still say boston',
#  'Umma life vava umma love lot dear',
#  'Thanks lot wish birthday Thanks make birthday truly memorable',
#  'Aight Ill hit get cash',
#  'would ip address test consider computer isnt minecraft server',
#  'know Grumpy old people mom like well lie always one play joke',
#  'Dont worry guess he busy',
#  'plural noun research',
#  'Going dinnermsg',
#  'Im ok wif co like 2 try new thing scar u dun like mah Cos u say loud',
#  'GENT try contact Last weekend draw show 1000 prize GUARANTEED Call 09064012160 Claim Code K52 Valid 12hrs 150ppm',
#  'Wa ur openin sentence formal Anyway im fine juz tt im eatin much n puttin weightHaha anythin special happen',
#  'enter cabin PA say Happy Bday Boss felt special askd 4 lunch lunch invite apartment go',
#  'winner U specially select 2 receive 1000 4 holiday flight inc speak live operator 2 claim 0871277810910pmin 18',
#  'Goodo Yes must speak friday eggpotato ratio tortilla need',
#  'Hmmmy uncle inform he pay school directly pls buy food',
#  'PRIVATE 2004 Account Statement 07742676969 show 786 unredeemed Bonus Points claim call 08719180248 Identifier Code 45239 Expires',
#  'URGENT Mobile award 2000 Bonus Caller Prize 5903 final try contact U Call Landline 09064019788 BOX42WR29C 150PPM',
#  'new address applespairsall malarky',
#  'Todays Voda number end 7548 select receive 350 award match please call 08712300220 quote claim code 4041 standard rate app',
#  'go sao mu today do 12',
#  'predict wat time finish buying',
#  'Good stuff',
#  'knowyetunde hasnt sent money yet sent text bother send dont involve anything shouldnt impose anything first place apologise',
#  'room',
#  'HEY GIRL R U HOPE U R WELL DEL R BAK LONG TIME C GIVE CALL SUM TIME LUCYxx',
#  'Kkhow much cost',
#  'Im home',
#  'Dear call Tmorrowpls accomodate',
#  'First answer question',
#  'Sunshine Quiz Wkly Q Win top Sony DVD player u know country Algarve Txt ansr 82277 150 SPTyrone',
#  'Want 2 get laid tonight Want real Dogging location sent direct 2 ur mob Join UKs large Dogging Network bt Txting GRAVEL 69888 Nt ec2a 31pmsg150p',
#  'haf msn yijuehotmailcom',
#  'call meet',
#  'check room befor activity',
#  'Youll rcv msg chat svc FREE Hardcore service text GO 69988 u get nothing u must Age Verify yr network try',
#  'Got c lazy type forgot lect saw pouch like v nice',
#  'K text youre way',
#  'Sir Waiting mail',
#  'swt thought Nver get tire little thing 4 lovable person Cozsomtimes little thing occupy big part Hearts Gud ni8',
#  'know pls open back',
#  'Yes see ya dot',
#  'Whats staff name take class u',
#  'FreeMsg havent reply text Im Randy sexy female live local Luv hear u Netcollex Ltd 08700621170150p per msg reply Stop end',
#  'Ummmawill call check inour life begin qatar pls pray hard',
#  'Ki delete contact',
#  'Sindu get job birla soft',
#  'wine flow im nevering',
#  'Yup thk cine well co need 2 go 2 plaza mah',
#  'Ok Ur typical reply',
#  'per request Melle Melle Oru Minnaminunginte Nurungu Vettam set callertune Callers Press 9 copy friend Callertune',
#  'everywhere dirt floor window even shirt sometimes open mouth come flow dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time do become one',
#  'Aaooooright work',
#  'Im leave house',
#  'Hello love get interview today happy good boy think meAre miss',
#  'Customer service annoncement New Years delivery wait Please call 07046744435 arrange delivery',
#  'winner U specially select 2 receive 1000 cash 4 holiday flight inc speak live operator 2 claim 0871277810810',
#  'Keep safe need miss already envy everyone see real life',
#  'New car house parentsi new job hand',
#  'Im love Im excite day spend make happy',
#  'PLS STOP bootydelious 32F invite friend Reply YES434 NO434 See wwwSMSacubootydelious STOP Send STOP FRND 62468',
#  'BangBabes Ur order way U receive Service Msg 2 download UR content U GoTo wap bangb tv UR mobile internetservice menu',
#  'place ur point e culture module already',
#  'URGENT try contact Last weekend draw show 900 prize GUARANTEED Call 09061701939 Claim code S89 Valid 12hrs',
#  'Hi frnd best way avoid missunderstding wit beloved one',
#  'Great escape fancy bridge need lager See tomo',
#  'Yes completely formclark also utter waste',
#  'Sir need AXIS BANK account bank address',
#  'Hmmm Thk sure get time hop ard Ya go 4 free abt Muz call u discus liao',
#  'time come later',
#  'Bloody hell cant believe forgot surname Mr Ill give u clue spanish begin',
#  'Well im gon na finish bath goodfine night',
#  'Let know youve get money carlos make call',
#  'U still go mall',
#  'Turns friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'Text doesnt reply let know log',
#  'Hi spoke MANEESHA V Wed like know satisfied experience Reply Toll Free Yes',
#  'lift hope offer money need Especially end month approach hurt study Anyways gr8 weekend',
#  'Lol U trust',
#  'ok gentleman treat dignity respect',
#  'guy close',
#  'Going nothing greatbye',
#  'Hello handsome find job lazy Working towards get back net mummy Wheres boytoy miss',
#  'Haha awesome minute',
#  'Please call customer service representative FREEPHONE 0808 145 4742 9am11pm guaranteed 1000 cash 5000 prize',
#  'get Xmas radio time get',
#  'jus reach home go bathe first si use net tell u finish k',
#  'unique enough Find 30th August wwwareyouuniquecouk',
#  'Im sorry Ive join league people dont keep touch mean great deal friend time even great personal cost great week',
#  'Hi finally complete course',
#  'stop however suggest stay someone able give or every stool',
#  'Hope youve settle new school year wishin gr8 day',
#  'Gud mrng dear hav nice day',
#  'u get person story',
#  'hamster dead Hey tmr meet 1pm orchard mrt',
#  'Hi Kate even hope see tomorrow bit bloody babyjontet Txt back u xxx',
#  'Found ENC ltgt',
#  'sent ltgt buck',
#  'Hello darlin ive finish college txt u finish u love Kate xxx',
#  'account refill successfully INR ltDECIMALgt KeralaCircle prepaid account balance Rs ltDECIMALgt Transaction ID KR ltgt',
#  'Goodmorning sleep ga',
#  'U call alter 11 ok',
#  'say like dat dun buy ericsson oso oredi lar',
#  'enter cabin PA say Happy Bday Boss felt special askd 4 lunch lunch invite apartment go',
#  'Aight yo dat straight dogg',
#  'please give u connection today ltDECIMALgt refund bill',
#  'shoot big load get ready',
#  'Whats bruv hope great break reward semester',
#  'Home always chat',
#  'Kkgoodstudy well',
#  'Yup noe leh',
#  'Sounds great home',
#  'Finally match head towards draw prediction',
#  'Tired havent slept well past night',
#  'Easy ahsen get select mean good',
#  'take exam march 3',
#  'Yeah think use gt atm register sure there anyway help let know sure ready',
#  'Ok prob Take ur time',
#  'o call ubandu run without instal hard diskyou use o copy important file system give repair shop',
#  'Sorry Ill call later',
#  'U say leh course nothing happen lar say v romantic jus bit lor thk e nite scenery nice leh',
#  '500 New Mobiles 2004 MUST GO Txt NOKIA 89545 collect todayFrom 1 www4tcbiz 2optout 08718726270150gbpmtmsg18',
#  'Would really appreciate call need someone talk',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt HORO follow ur star sign e g HORO ARIES',
#  'Hey company elama po mudyadhu',
#  'Life strict teacher Bcoz Teacher teach lesson amp conduct exam Life first conduct Exam amp teach Lessons Happy morning',
#  'Dear good morning',
#  'Get gandhipuram walk cross cut road Right side ltgt street road turn first right',
#  'Dear go rubber place',
#  'Sorry battery die yeah Im',
#  'Yeshere tv always available work place',
#  'Text meet someone sexy today U find date even flirt U Join 4 10p REPLY NAME AGE eg Sam 25 18 msg recdthirtyeight penny',
#  'print oh ltgt come upstairs',
#  'ill little closer like bus stop street',
#  'youwhen wil reach',
#  'New Theory Argument win SITUATION loses PERSON dont argue ur friend kick amp say Im always correct',
#  'U 447801259231 secret admirer look 2 make contact Ufind Rreveal think UR specialcall 09058094597',
#  'Tomarrow final hearing laptop case cant',
#  'PLEASSSSSSSEEEEEE TEL V AVENT DONE SPORTSx',
#  'Okay shin meant signing sound well',
#  'Although told u dat im baig face watch really like e watch u give co fr u Thanx 4 everything dat uve do today im touch',
#  'U dont remember old commercial',
#  'late say website didnt dont slipper',
#  'ask call ok',
#  'Kallis wont bat 2nd inning',
#  'didnt work oh Ok goodnight Ill fix ready time wake dearly miss good night sleep',
#  'Congratulations ur award 500 CD voucher 125gift guaranteed Free entry 2 100 wkly draw txt MUSIC 87066 TnCs wwwLdewcom1win150ppmx3age16',
#  'Ranjith cal drpd Deeraj deepak 5min hold',
#  'Wen ur lovable bcums angry wid u dnt take seriously Coz angry childish n true way show deep affection care n luv kettoda manda nice day da',
#  'doinghow',
#  'Ups 3days also shipping company take 2wks way usps take week get lag may bribe nipost get stuff',
#  'Im back lem know youre ready',
#  'Dont necessarily expect do get back though Im headin',
#  'Mmm yummy babe Nice jolt suzy',
#  'lover need',
#  'try contact reply offer Video Handset 750 anytime network min UNLIMITED TEXT Camcorder Reply call 08000930705',
#  'Im park next MINI come today think',
#  'Yup',
#  'Anyway im go shopping Cos si do yet Dun disturb u liao',
#  'LUTON 0125698789 RING UR AROUND H',
#  'Hey really horny want chat see naked text hot 69698 text charge 150pm unsubscribe text stop 69698',
#  'Dint come u',
#  'Wana plan trip sometme',
#  'sure yet still try get hold',
#  'Ur ringtone service change 25 Free credit Go club4mobilescom choose content Stop txt CLUB STOP 87070 150pwk Club4 PO Box1146 MK45 2WT',
#  'evo download flash Jealous',
#  'Ringtone Club Get UK single chart mobile week choose top quality ringtone message free charge',
#  'Come mu sort narcotic situation',
#  'Night end another day morning come special way May smile like sunny ray leaf worry blue blue bay',
#  'HMV BONUS SPECIAL 500 pound genuine HMV voucher answer 4 easy question Play Send HMV 86688 infowww100percentrealcom',
#  'Usf guess might well take 1 car',
#  'objection bf come',
#  'Thanx',
#  'Tell rob mack gf theater',
#  'Awesome Ill see bit',
#  'sent type food like',
#  'do hand Celebrations full swing yet',
#  'get call tool',
#  'Wen u miss someone person definitely special u person special miss Keepintouch gdeve',
#  'Ok ask money far',
#  'Okie',
#  'Yeah think usual guy still pass last night get ahold anybody let know Ill throw',
#  'K might come tonight class let early',
#  'Ok',
#  'hi baby im cruisin girl friend r u 2 give call hour home thats alright fone fone love jenny xxx',
#  'life Means lot love life love people life world call friend call World Ge',
#  'Dearshall mail tonitebusy streetshall update tonitethings look okvarunnathu edukkukayee raksha ollubut good one real sense',
#  'Hey told name gautham ah',
#  'Haf u found feel stupid da v cam work',
#  'Oops 4 get bit',
#  'much buzy',
#  'accidentally delete message Resend please',
#  'TMobile customer may claim FREE CAMERA PHONE upgrade pay go sim card loyalty Call 0845 021 3680Offer end 28thFebTCs apply',
#  'Unless situation GO GURL would appropriate',
#  'Hurt Tease Make cry end life die plz keep one rise grave say STUPID MISS U NICE DAY BSLVYL',
#  'cant pick phone right Pls send message',
#  'Need coffee run tomoCant believe time week already',
#  'Awesome remember last time get somebody high first time diesel V',
#  'Shit really shock scary cant imagine second Def night u think somewhere could crash night save taxi',
#  'Oh way food fridge Want go meal tonight',
#  'womdarfull actor',
#  'SMS ac Blind Date 4U Rodds1 21m Aberdeen United Kingdom Check httpimg sm acWicmb3cktz8r74 Blind Dates send HIDE',
#  'Yup remb think book',
#  'Jos ask u wana meet',
#  'Lol yes friendship hang thread cause u wont buy stuff',
#  'TheMob Check new selection content Games Tones Gossip babe sport Keep mobile fit funky text WAP 82468',
#  'garage key arent bookshelf',
#  'Today ACCEPT DAYU Accept Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd rply mean enemy',
#  'Think ur smart Win 200 week weekly quiz text PLAY 85222 nowTCs WinnersClub PO BOX 84 M26 3UZ 16 GBP150week',
#  'say hell give call friend get money he definitely buying end week',
#  'Hi way u 2day normal waythis real UR uniqueI hope know u 4 rest mylife Hope u find wot lose',
#  'make day great day',
#  'Kkadvance happy pongal',
#  'Hmmm Guess go 4 kb n power yoga Haha dunno tahan power yoga anot Thk get lo oso forgot liao',
#  'really dude friend im afraid',
#  'December mobile 11mths entitle update late colour camera mobile Free Call Mobile Update Co FREE 08002986906',
#  'Coffee cake guess',
#  'Merry Christmas babe love ya kiss',
#  'Hey dont go watch x men lunch Haha',
#  'cud u tell ppl im gona b bit l8 co 2 bus hav gon past co full im still waitin 4 1 Pete x',
#  'would great Well Guild Could meet Bristol road somewhere get touch weekend plan take flight good week',
#  'problem',
#  'callsmessagesmissed call',
#  'Hi dahow today class',
#  'Id say thats good sign well know track record reading woman',
#  'Cool text youre park',
#  'Im reading text sent meant joke read light',
#  'Kkapo kgood movie',
#  'Maybe could get book tomo return immediately something',
#  'Call Germany 1 penny per minute Call fix line via access number 0844 861 85 85 prepayment Direct access',
#  'chance might evaporate soon violate privacy steal phone number employer paperwork cool Please contact report supervisor',
#  'Valentines Day Special Win 1000 quiz take partner trip lifetime Send GO 83600 150pmsg rcvd CustCare08718720201',
#  'TaDaaaaa home babe still',
#  'Cool come havent win din',
#  'sleepingand surf',
#  'Sorry Ill call later',
#  'U call right Call hand phone',
#  'Ok thats great thanx lot',
#  'take post come must 1000 text Happy reading one wiv hello caroline end favourite Bless',
#  'u hiding stranger',
#  'interested like',
#  'sister clear two round birla soft yesterday',
#  'Gudnitetcpractice go',
#  'Dis yijue jus saw ur mail case huiming havent sent u num Dis num',
#  'One small prestige problem',
#  'Fancy shag doInterested sextextukcom txt XXUK SUZY 69876 Txts cost 150 per msg TnCs website X',
#  'check Really miss see Jeremiah great month',
#  'Nah cant help Ive never iphone',
#  'youre car hour half Im go apeshit',
#  'TODAY Sorry day ever angry ever misbehave hurt plz plz SLAP URSELF Bcoz ur fault Im basically GOOD',
#  'Yo guy ever figure much need alcohol Jay try figure much safely spend weed',
#  'ltgt ISH MINUTES 5 MINUTES AGO WTF',
#  'Thank callingForgot say Happy Onam SirjiI fine remember met insurance personMeet Qatar Insha AllahRakhesh ex Tata AIG join TISSCOTayseer',
#  'Congratulations ur award 500 CD voucher 125gift guaranteed Free entry 2 100 wkly draw txt MUSIC 87066 TnCs wwwLdewcom1win150ppmx3age16',
#  'Ur cashbalance currently 500 pound maximize ur cashin send CASH 86688 150pmsg CC 08708800282 HGSuite3422Lands RowW1J6HL',
#  'Im actor work work even sleep late Since im unemployed moment ALWAYS sleep late youre unemployed every day saturday',
#  'Hello get st andrewsboy long way cold keep post',
#  'Ha ha cool cool chikku chikkuDB',
#  'Oh ok prob',
#  'Check audreys status right',
#  'Busy Trying finish new year look forward finally meeting',
#  'Good afternoon sunshine dawn day refresh happy alive breathe air smile think love always',
#  'Well know Z take care worry',
#  'UpdateNow Xmas Offer Latest Motorola SonyEricsson Nokia FREE Bluetooth Double Mins 1000 Txt Orange Call MobileUpd8 08000839402 call2optoutF4Q',
#  'discount code RP176781 stop message reply stop wwwregalportfoliocouk Customer Services 08717205546',
#  'Wat uniform get',
#  'Cool text youre ready',
#  'Hello boytoy Geeee miss already woke wish bed cuddle love',
#  'spoil bed well',
#  'Im go bath msg next ltgt min',
#  'cant keep talk people sure pay agree price pls tell want really buy much willing pay',
#  'Thanks Ringtone Order Reference T91 charge GBP 4 per week unsubscribe anytime call customer service 09057039994',
#  'say happen',
#  'could see mei didt recognise Face',
#  'Well there lot thing happen Lindsay New year sigh bar Ptbo blue heron something go',
#  'Keep payasam rinu brings',
#  'taught Ranjith sir call sm like Becaus he verify project Prabu told today pa dont mistake',
#  'guess thats worried must know there way body repair im quite sure shouldnt worry Well take slow First test guide ovulation relax Nothing youve say reason worry ill keep followin',
#  'Yeah sure give couple minute track wallet',
#  'Hey leave big deal take care',
#  'Hey late ah Meet 945',
#  'Double min txts 4 6months FREE Bluetooth Orange Available Sony Nokia Motorola phone Call MobileUpd8 08000839402 call2optoutN9DX',
#  'take Mr owl 3 lick',
#  'Customer place call',
#  'Mm time dont like fun',
#  '4mths half price Orange line rental late camera phone 4 FREE phone 11mths Call MobilesDirect free 08000938767 update or2stoptxt',
#  'Yup lunch buffet U eat already',
#  'Huh late Fr dinner',
#  'Hey sat go intro pilate kickboxing',
#  'Morning ok',
#  'Yes think office lap room think thats last day didnt shut',
#  'Pick bout 730ish time go',
#  'performance award calculate every two monthnot current one month period',
#  'actually sleep still might u call back text gr8 rock si send u text wen wake',
#  'always put business put picture as facebook one open people ive ever met would think picture room would hurt make feel violate',
#  'Good even Sir Al Salam Wahleykkumsharing happy newsBy grace God get offer TayseerTISSCO joinedHope fineInshah Allahmeet sometimeRakheshvisitor India',
#  'Hmmmkbut want change field quickly dai wan na get system administrator network administrator',
#  'FREE RINGTONE text FIRST 87131 poly text GET 87131 true tone Help 0845 2814032 16 1st free tone 3x150pw end txt stop',
#  'Dear chechi talk',
#  'hair cream ship',
#  'None thats happen til get though',
#  'Yep great loxahatchee xmas tree burning ltgt start hour',
#  'Haha get use drive usf man know lot stoner',
#  'well slightly disastrous class pm fav darling Hope day ok Coffee wld good cant stay late tomorrow time place always',
#  'Hello Good week Fancy drink something later',
#  'Headin towards busetop',
#  'Messagesome text miss SenderName Missing Number Missing SentDate miss Missing U lot thats everything miss sent via fullonsmscom',
#  'Come room point iron plan weekend',
#  'Cos want thing',
#  'Okies Ill go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'Bring home Wendy',
#  '100 date service call 09064012103 box334sk38ch',
#  'Whatsup Dont u want sleep',
#  'Alright new goal',
#  'FREE entry 250 weekly competition text word WIN 80086 18 TC wwwtxttowincouk',
#  'Alright Ill head minute text meet',
#  'Send logo 2 ur lover 2 name join heart Txt LOVE NAME1 NAME2 MOBNO eg LOVE ADAM EVE 07123456789 87077 Yahoo POBox36504W45WQ TxtNO 4 ad 150p',
#  'Yesfrom last week im take live call',
#  'Someone contact date service enter phone fancy find call landline 09111032124 PoBox12n146tf150p',
#  'Siva hostel aha',
#  'URGENT Mobile number award 2000 prize GUARANTEED Call 09058094455 land line Claim 3030 Valid 12hrs',
#  'Send ur friend receive something ur voice speak expression 1childish 2naughty 3Sentiment 4rowdy 5ful attitude 6romantic 7shy 8Attractive 9funny ltgt irritate ltgt lovable reply',
#  'Ok Shell ok guess',
#  'aathiwhere dear',
#  'pain urination thing else',
#  '7 esplanade mind give lift co get car today',
#  'wnt buy BMW car urgentlyits vry urgentbut hv shortage ltgt Lacsthere source arng dis amt ltgt lacsthats prob',
#  'home watch tv lor',
#  'usually take fifteen fuck minute respond yes question',
#  'Congrats Nokia 3650 video camera phone Call 09066382422 Calls cost 150ppm Ave call 3mins vary mobile 16 Close 300603 post BCM4284 Ldn WC1N3XX',
#  'Booked ticket pongal',
#  'available Im like right around hillsborough amp ltgt th',
#  'message sent askin ltgt dollar Shoul pay ltgt ltgt',
#  'Ask g iouri Ive told story like ten time already',
#  'long applebees fuck take',
#  'Hi hope u get txtjourney hasnt gdnow 50 min late think',
#  'like love arrange',
#  'Yeshe really greatbhaji told kallis best cricketer sachin worldvery tough get',
#  'suppose wake gt',
#  'Oic saw tot din c found group liao',
#  'Sorry Ill call later',
#  'HEY HEY WERETHE MONKEESPEOPLE SAY MONKEYAROUND HOWDY GORGEOUS HOWU DOIN FOUNDURSELF JOBYET SAUSAGELOVE JEN XXX',
#  'Sorry battery die come Im get gram wheres place',
#  'Well do blimey exercise yeah kinda remember wot hmm',
#  'wont get concentration dear know mind everything',
#  'LOL make plan new year',
#  '10 min later k',
#  'hank lotsly',
#  'Thanks hope good day today',
#  'Kkwhat detail want transferacc enough',
#  'Ok tell stay Yeah tough optimistic thing improve month',
#  'Loan purpose 500 75000 Homeowners Tenants welcome previously refuse still help Call Free 0800 1956669 text back help',
#  'Si si think ill go make oreo truffle',
#  'LOOK AMY URE BEAUTIFUL INTELLIGENT WOMAN LIKE U LOT KNOW U DONT LIKE LIKE DONT WORRY',
#  'hope thats result consistently intelligent kind Start ask practicum link keep ear open best ttyl',
#  '120 call cost guess isnt bad Miss ya need ya want ya love ya',
#  'Going thru different feelingwavering decision cop individualtime heal everything believe',
#  'u go phone gon na die stay',
#  'Great Never well day give even reason thank God',
#  'UpgrdCentre Orange customer may claim FREE CAMERA PHONE upgrade loyalty Call 0207 153 9153 Offer end 26th July TCs apply Optout available',
#  'Sorry Ill call later ok bye',
#  'Ok way railway',
#  'great princess love give receive oral Doggy style fave position enjoy make love ltgt time per night',
#  'dont put stuff road keep get slippery',
#  'go ride bike',
#  'Yup need Ill jus wait 4 e rain 2 stop',
#  'many company Tell language',
#  'okmail Dear Dave final notice collect 4 Tenerife Holiday 5000 CASH award Call 09061743806 landline TCs SAE Box326 CW25WX 150ppm',
#  'long since scream princess',
#  'Nothing meant money enters account bank remove flat rate Someone transfer ltgt account ltgt dollar get remove bank differ charge also differbe sure trust 9ja person send account detail co',
#  'Want 2 get laid tonight Want real Dogging location sent direct 2 ur Mob Join UKs large Dogging Network txting MOAN 69888Nyt ec2a 31pmsg150p',
#  'Nice line say broken heart Plz dont cum 1 time infront wise trust U Good 9t',
#  'Ok Im gon na head usf like fifteen minute',
#  'Love aathilove u lot',
#  'Tension ahwhat machiany problem',
#  'K pick another 8th youre do',
#  'Whenre guy get back G say think stay mcr',
#  'Almost see u sec',
#  'Yo carlos friend already ask work weekend',
#  'Watching tv lor',
#  'Thank baby cant wait taste real thing',
#  'change fb jaykwon thuglyfe falconerf',
#  'win really 1 side long time',
#  'FREE MESSAGE Activate 500 FREE Text Messages reply message word FREE term condition visit www07781482378com',
#  'Dear reach railway happen',
#  'Depends quality want type sent boye fade glory 6 want ralphs maybe 2',
#  'think ive fix send test message',
#  'Sorry man account dry would want could trade back half could buy shit credit card',
#  'Congrats 1 year special cinema pas 2 call 09061209465 C Suprman V Matrix3 StarWars3 etc 4 FREE bx420ip45we 150pm Dont miss',
#  'Sorryin meeting Ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'Got meh',
#  'Nope Think go monday Sorry reply late',
#  'told accenture confirm true',
#  'Kate jackson rec center 7ish right',
#  'Dear reache room',
#  'Fighting world easy u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'come',
#  'Check nuerologist',
#  'Lolnice go fish water',
#  '123 Congratulations week competition draw u 1450 prize claim call 09050002311 b4280703 TCsstop SMS 08718727868 18 150ppm',
#  'wait e car dat bore wat Cos wait outside get nothing 2 home stuff watch tv wat',
#  'Maybe westshore hyde park village place near house',
#  'know hows anthony bring money Ive school fee pay rent stuff like Thats need help friend need',
#  'Whats significance',
#  'opinion 1 2 Jada 3 Kusruthi 4 Lovable 5 Silent 6 Spl character 7 mature 8 Stylish 9 Simple Pls reply',
#  '8 late g still scrounge ammo want give new ak try',
#  'Prabhaim sorydarealyfrm heart im sory',
#  'Lol ok forgiven',
#  'Nojst change tat',
#  'guaranteed late Nokia Phone 40GB iPod MP3 player 500 prize Txt word COLLECT 83355 IBHltd LdnW15H 150pMtmsgrcvd18',
#  'Sno competition',
#  'Boltblue tone 150p Reply POLY MONO eg POLY3 1 Cha Cha Slide 2 Yeah 3 Slow Jamz 6 Toxic 8 Come STOP 4 tone txt',
#  'credit topped httpwwwbubbletextcom renewal Pin tgxxrz',
#  'way transport less problematic sat night way u want ask n join bday feel free need know definite no book fri',
#  'Usually person unconscious thats child adult may behave abnormally Ill call',
#  'thats ebay might less elsewhere',
#  'Shall come get pickle',
#  'gon na go get taco',
#  'Thats rude campus',
#  'URGENT Mobile award 2000 Bonus Caller Prize 020903 2nd attempt contact Call 08718729755 BOX95QU',
#  'Hi wont b ard 4 christmas enjoy n merry xmas',
#  'Todays Offer Claim ur 150 worth discount voucher Text YES 85023 SavaMob member offer mobile Cs 08717898035 300 Sub 16 Unsub reply X',
#  'Yes pretty lady like single',
#  'recieve tone within next 24hrs Terms condition please see Channel U Teletext Pg 750',
#  'Jay say youre doublefaggot',
#  'PRIVATE 2003 Account Statement 07815296484 show 800 unredeemed SIM point Call 08718738001 Identifier Code 41782 Expires 181104',
#  'Todaysundaysunday holidayso work',
#  'Gudnitetcpractice go',
#  'Ill late',
#  'Ive call hop l8r malaria know miss guy miss Bani big pls give love especially great day',
#  'Good afternoon love go day hope maybe get lead job think boytoy send passionate kiss across sea',
#  'Probably gon na see later tonight lt',
#  'maybe fat finger press button doesnt know',
#  'Ummmmmaah Many many happy return day dear sweet heart HAPPY BIRTHDAY dear',
#  'tirupur da start office call',
#  'wwwApplausestorecom MonthlySubscription50pmsg max6month TCsC web age16 2stop txt stop',
#  'famous quote develop ability listen anything unconditionally without lose temper self confidence mean MARRIED',
#  'go college pa else ill come self Pa',
#  '4 oclock mine bash flat plan',
#  'girl stay bed girl doesnt need recovery time Id rather pas fun cooped bed',
#  'special',
#  'know need get hotel get invitation apologise Cali sweet come english bloke weddin',
#  'Sorry take long omw',
#  'Wait ltgt min',
#  'Ok give 5 minute think see BTW youre alibi cut hair whole time',
#  'Imagine finally get sink bath put pace maybe even eat left also imagine feel cage cock surround bath water remind always own Enjoy cuck',
#  'Hurry Ive weeddeficient like three day',
#  'Sure get acknowledgement astoundingly tactless generally faggy demand blood oath fo',
#  'Ok Every night take warm bath drink cup milk youll see work magic still need loose weight know',
#  'Ill look fry pan case cheap book perhaps thats silly fry pan isnt likely book',
#  'Well uv cause mutation Sunscreen like essential thesedays',
#  'lunchyou onlinewhy',
#  'know friend already told',
#  'Hi Princess Thank pic pretty',
#  'Aiyo U always c ex one dunno abt mei reply First time u reply fast lucky workin huh get bao ur sugardad ahgee',
#  'Hi msg meim office',
#  'Thanx 4 e brownie v nice',
#  'Geeeee love much barely stand',
#  'GENT try contact Last weekend draw show 1000 prize GUARANTEED Call 09064012160 Claim Code K52 Valid 12hrs 150ppm',
#  'Fuck babe miss already know Cant let send money towards net need want crave',
#  'Ill call u 2mrw ninish address icky American freek wont stop callin 2 bad Jen k eh',
#  'Oooh bed ridden ey think',
#  'anyways go gym whatever love smile hope ok good day babe miss much already',
#  'Love Daddy make scream pleasure go slap as dick',
#  'WOT U WAN NA MISSY',
#  'Yar lor wait 4 mum 2 finish sch lunch lor whole morning stay home clean room room quite clean Hee',
#  'know lab goggles go',
#  'open door',
#  'Waiting call',
#  'Nope wait sch 4 daddy',
#  '1000 cash 2000 prize claim call09050000327',
#  'Im tire argue week week want ill',
#  'wait 4 sch finish ard 5',
#  'mobile number 5000 claim call u back ring claim hot line 09050005321',
#  'Arngd marriage u r walkin unfortuntly snake bite u bt love marriage dance frnt snake amp sayin Bite bite',
#  'Huh early dinner outside izzit',
#  'Ok anyway need change say',
#  'try contact reply offer 750 min 150 textand new video phone call 08002988890 reply free delivery tomorrow',
#  'exwife able kid want kid one day',
#  'hows scotland Hope show JJC tendency Take care Live dream',
#  'Tell u headache want use 1 hour sick time',
#  'dun thk ill quit yet Hmmm go jazz Yogasana oso go meet em lesson den',
#  'Pete please ring meive hardly gotany credit',
#  'Ya srsly well yi tho',
#  'Im meeting call later',
#  'ur chance win 250 wkly shopping spree TXT SHOP 80878 TsCs wwwtxt2shopcom custcare 08715705022 1x150pwk',
#  'specially select receive 2000 pound award Call 08712402050 line close Cost 10ppm 16 TCs apply AG Promo',
#  'PRIVATE 2003 Account Statement 07753741225 show 800 unredeemed point Call 08715203677 Identifier Code 42478 Expires 241004',
#  'still grand prix',
#  'met stranger choose friend long world stand friendship never end Lets Friends forever Gud nitz',
#  'great',
#  'Gud mrng dear nice day',
#  'important customer service announcement Call FREEPHONE 0800 542 0825',
#  'exhaust train morning much wine pie sleep well',
#  'Im go buy mum present ar',
#  'Mind blastin Tsunamis occur Rajnikant stop swim Indian OceanD',
#  'u send home first ok lor Im ready yet',
#  'Speaking cash yet',
#  'happy come noon',
#  'Meet lunch la',
#  'TaKe CaRE n gET WeLL sOOn',
#  'XCLUSIVECLUBSAISAI 2MOROW 285 SOIREE SPECIALE ZOUK NICHOLS PARISFREE ROSES 2 LADIES info 0794674629107880867867',
#  'meant say cant wait see u get bore bridgwater banter',
#  'Neva mind ok',
#  'fine imma get drink somethin Want come find',
#  '22 day kick Euro2004 U kept date late news result daily remove send GET TXT STOP 83222',
#  'valentine game Send dis msg ur friend 5 answer r someone really love u Ques colour suit bestrply',
#  'many dependent',
#  'THANX4 TODAY CER NICE 2 CATCH AVE 2 FIND TIME OFTEN OH WELL TAKE CARE C U SOONC',
#  'call say himthen choose future',
#  'Happy valentine day know early hundred handsomes beauty wish thought finish aunty uncle 1st',
#  'like v shock leh Cos tell shuhui like tell leona also Like dat almost know liao get ask abt ur reaction lor',
#  'family happiness',
#  'come n pick Come immediately aft ur lesson',
#  'Let snow Let snow kind weather brings ppl together friendship grow',
#  'Dear get ltgt dollar hi hi',
#  'Good word word may leave u dismay many time',
#  'MAKE SURE ALEX KNOWS BIRTHDAY FIFTEEN MINUTES FAR YOURE CONCERNED',
#  'sorry get thing may pub later',
#  'Nah straight bring bud drink something thats actually little useful straight cash',
#  'Haha good hear Im officially paid market 8th',
#  'many lick take get center tootsie pop',
#  'Yup thk r e teacher say make face look longer Darren ask 2 cut short',
#  'New TEXTBUDDY Chat 2 horny guy ur area 4 25p Free 2 receive Search postcode gaytextbuddycom TXT ONE name 89693',
#  'Todays Vodafone number end 4882 select receive 350 award number match call 09064019014 receive 350 award',
#  'Please dont say like Hi hi hi',
#  'Thank u',
#  'Oh forward message thought send',
#  'Got Seventeen pound seven hundred ml hope ok',
#  'Dear Voucher Holder 2 claim week offer PC go httpwwwetlpcoukexpressoffer TsCs apply2 stop text txt STOP 80062',
#  'n funny',
#  'Sweetheart hope kind day one load reason smile Biola',
#  'login dat time Dad fetch home',
#  'shower baby',
#  'askd u question hour answer',
#  'Well imma definitely need restock thanksgiving Ill let know Im',
#  'say kiss kiss cant sound effect gorgeous man isnt Kind person need smile brighten day',
#  'Probably gon na swing wee bit',
#  'Ya nice ready thursday',
#  'Allo brave bus take train triumphed mean bham jolly good rest week',
#  'Watching cartoon listen music amp eve go temple amp church u',
#  'mind ask happen dont say uncomfortable',
#  'PRIVATE 2003 Account Statement show 800 unredeemed point Call 08715203694 Identifier Code 40533 Expires 311004',
#  'prob send email',
#  '1000 cash 2000 prize claim call09050000327 TC RSTM SW7 3SS 150ppm',
#  'Thats cool Sometimes slow gentle Sonetimes rough hard',
#  'Im gon na say Sorry would normal start panic time Sorry see Tuesday',
#  'Wait know wesley town bet hella drug',
#  'Fine miss much',
#  'u get person story',
#  'Tell drug dealer get impatient',
#  'Sun cant come earth send luv ray cloud cant come river send luv rain cant come meet U send care msg U Gud evng',
#  'place man',
#  'doesnt make sense take unless free need know wikipediacom',
#  '88800 89034 premium phone service call 08718711108',
#  'sea lay rock rock envelope envelope paper paper 3 word',
#  'mum repent',
#  'Sorry go home first Daddy come fetch later',
#  'Leave de Start Prepare next',
#  'Yes baby study position kama sutra',
#  'En chikku nange bakra msg kalstiyathen teacoffee',
#  'Carlosll minute still need buy',
#  'pay ltDECIMALgt lakh',
#  'good even Ttyl',
#  'u receive msg',
#  'Ho ho big belly laugh See ya tomo',
#  'SMS ac sun0819 post HELLOYou seem cool want say hi HI Stop Send STOP 62468',
#  'Get ur 1st RINGTONE FREE Reply msg TONE Gr8 TOP 20 tone phone every week 150 per wk 2 opt send STOP 08452810071 16',
#  'Ditto wont worry say ANYTHING anymore Like say last night whatever want ill Peace',
#  'Ive get ltgt way could pick',
#  'dont knw pa drink milk',
#  'Maybe Say hi find get card Great escape wetherspoons',
#  'Piggy r u awake bet ure still sleep Im go 4 lunch',
#  'Cause Im freaky lol',
#  'Missed call cause yell scrappy Miss u Cant wait u come home Im lonely today',
#  'hex place talk Explain',
#  'log 4 wat sdryb8i',
#  'xy go 4 e lunch',
#  'Hi Im sue 20 year old work lapdancer love sex Text live Im bedroom text SUE 89555 TextOperator G2 1DA 150ppmsg 18',
#  'want ask wait 4 finish lect Cos lect finish hour anyway',
#  'finish work yet',
#  'Every King Crying Baby Every Great Building Map Imprtant U r TODAY U Wil Reach TOMORW Gud ni8',
#  'DearMe cherthalain case u r come cochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engage an holiday',
#  'Thanks love torch bold',
#  'Forwarded 448712404000Please CALL 08712404000 immediately urgent message wait',
#  'farm open',
#  'Sorry trouble u buy 4d dad 1405 1680 1843 2 big 1 small sat n sun Thanx',
#  'sister law hope great month say hey Abiola',
#  'purchase stuff today mail po box number',
#  'Ah poop Looks like ill prob send laptop get fix cuz gpu problem',
#  'Good Good job like entrepreneur',
#  'Aight close still around alexs place',
#  'meet corporation st outside gap see mind work',
#  'Mum ask buy food home',
#  'Ku also dont msg reply msg',
#  'much r willing pay',
#  'Sorry Ill call later',
#  'important prevent dehydration give enough fluid',
#  'Thats bit weird even suppose happen good idea sure pub',
#  'True deari sat pray even felt soso smsd time',
#  'dont think get away trek long family town sorry',
#  'wan na gym harri',
#  'Quite late lar Ard 12 anyway wun b drivin',
#  'review KEEP fantastic Nokia NGage game deck Club Nokia go 2 wwwcnupdatescomnewsletter unsubscribe alert reply word',
#  '4mths half price Orange line rental late camera phone 4 FREE phone 11mths Call MobilesDirect free 08000938767 update or2stoptxt TCs',
#  'Height Confidence Aeronautics professor wer calld amp wer askd 2 sit aeroplane Aftr sat wer told dat plane w make student Dey hurry plane Bt 1 didnt move saidif make studentsthis wont even start Datz confidence',
#  'seem like weird timing night g want come smoke day shitstorm attribute always come make everyone smoke',
#  '08714712388 10am7pm Cost 10p',
#  'Save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell ill tell',
#  '449071512431 URGENT 2nd attempt contact UU 1250 CALL 09071512433 b4 050703 TCsBCM4235WC1N3XX callcost 150ppm mobilesvary max7 50',
#  'Book lesson msg call work sth Im go get spec membership PX3748',
#  'guaranteed 1000 cash 2000 prize claim yr prize call customer service representative 08714712394 10am7pm',
#  'Macha dont feel upseti assume mindsetbelieve one even wonderful plan usLET LIFE BEGIN AGAINcall anytime',
#  'Oh Send address',
#  'Sfine Anytime best',
#  'wondar full flim',
#  'Ya even cooky jelly',
#  'world run stillmaybe feel sameso itor admiti madthen correctionor let call lifeand keep run worldmay u r also runninglets run',
#  'Got look scrumptious daddy want eat night long',
#  'co lar im ba dao ok 1 pm lor u never ask go ah say u would ask fri say u ask today',
#  'Alright omw get ta change order half8th',
#  'Exactly Anyways far jide study visit',
#  'Dunno u ask',
#  'Email AlertFrom Jeri StewartSize 2KBSubject Lowcost prescripiton drvgsTo listen email call 123',
#  'didnt Spring come early yay',
#  'Lol wont feel bad use money take steak dinner',
#  'Even u dont get trouble convincingjust tel twice tel neglect msg dont c read itjust dont reply',
#  'Leaving qatar tonite search opportunityall go fastpls add ur prayer dearRakhesh',
#  'one talk',
#  'Thanks look really appreciate',
#  'Hi Customer Loyalty OfferThe NEW Nokia6650 Mobile 10 TXTAUCTION Txt word START 81151 get 4TCtxt TC 150pMTmsg',
#  'Wish',
#  'Haha mayb ure rite U know well Da feel like someone gd lor U faster go find one gal group attach liao',
#  'Yes Glad make',
#  'well little time Thing good time ahead',
#  'get room soon hadnt put clock back til 8 shout everyone get realise 7 wahay another hour bed',
#  'Ok may free gym',
#  'Men like shorter lady Gaze eye',
#  'Dunno jus say go lido time 930',
#  'promise take good care princess run Please send pic get chance Ttyl',
#  'U subscribed best Mobile Content Service UK 3 per 10 day send STOP 82324 Helpline 08706091795',
#  'reason weve spoken year Anyways great week best exam',
#  'monday next week Give full gist',
#  'realize 40 year well thousand old lady run around tattoo',
#  'important customer service announcement PREMIER',
#  'Dont gim lip caveboy',
#  'get library',
#  'Realy sorryi dont recognise number confuse r u please',
#  'didnt holla',
#  'Cant think anyone spare room top head',
#  'Faith make thing possibleHope make thing workLove make thing beautifulMay three ChristmasMerry Christmas',
#  'U make appointment',
#  'Call youcarlos isare phone vibrate act might hear text',
#  'Romantic Paris 2 night 2 flight 79 Book 4 next year Call 08704439680TsCs apply',
#  'grandma Oh dear u still ill felt Shit morning think hungover Another night leave sat',
#  'Urgent Ur 500 guaranteed award still unclaimed Call 09066368327 closingdate040902 claimcode M39M51 150pmmorefrommobile2BremovedMobyPOBox734LS27YF',
#  'Nothing jus tot u would ask co u ba gua go mt faber yest Yest jus go already mah today go Jus call lor',
#  'Wishing family Merry X ma HAPPY NEW Year advance',
#  'UR award City Break could WIN 200 Summer Shopping spree every WK Txt STORE 88039 SkilGme TsCs087147403231WinawkAge16 150perWKsub',
#  'Im nt goin get somethin unless meetin 4 dinner lor Haha wonder go ti time',
#  'Sorry Ill call later',
#  'cant pick phone right Pls send message',
#  'Lol know Theyre dramatic Schools already close tomorrow Apparently cant drive inch snow suppose get',
#  'get anywhere damn job hunt',
#  'Lol U drunkard hair moment Yeah still 4 tonight Wats plan',
#  'idc get weaseling way shit twice row',
#  'wil ltgt minute Got space',
#  'sleepingand surf',
#  'Thanks pick trash',
#  'dont go tell friend youre sure want live smoke much spend hour beg come smoke',
#  'Hi Kate lovely see tonight ill phone tomorrow get sing guy give card xxx',
#  'Happy New year dear brother really miss get number decide send text wish happiness Abiola',
#  'mean get door',
#  'opinion 1 2 Jada 3 Kusruthi 4 Lovable 5 Silent 6 Spl character 7 mature 8 Stylish 9 Simple Pls reply',
#  'Hmmm thought say 2 hour slave 3 late punish',
#  'Beerage',
#  'important customer service announcement PREMIER Call FREEPHONE 0800 542 0578',
#  'Dont think turn like randomlly within 5min opening',
#  'suppose couldnt make shes still town though',
#  'time fix spell sometimes get completely diff word Go figure',
#  'Ever thought living good life perfect partner txt back NAME AGE join mobile community 100pSMS',
#  '5 Free Top Polyphonic Tones call 087018728737 National Rate Get toppoly tune sent every week text SUBPOLY 81618 3 per pole UnSub 08718727870',
#  'Gud mrng dear hav nice day',
#  'hop enjoy game yesterday Sorry ive touch pls know fondly bein thot great week Abiola',
#  'e best 4 ur drive tmr',
#  'YWHERE U DOGBREATH SOUNDING LIKE JAN C THATS AL',
#  'Omg want scream weigh lose weight Woohoo',
#  'generally isnt one uncountable noun u dictionary piece research',
#  'really get hang around',
#  'Orange customer may claim FREE CAMERA PHONE upgrade loyalty Call 0207 153 9996 Offer end 14thMarch TCs apply Optout availa',
#  'Petey boy whereare friendsare theKingshead come canlove Nic',
#  'Ok msg u b4 leave house',
#  'Gim ltgt minute ago',
#  'Last Chance Claim ur 150 worth discount voucher today Text SHOP 85023 SavaMob offer mobile Cs SavaMob POBOX84 M263UZ 300 Sub 16',
#  'Appt ltTIMEgt fault u dont listen told u twice',
#  'FREE 1st week No1 Nokia tone 4 ur mobile every week txt NOKIA 8077 Get txting tell ur mate wwwgetzedcouk POBox 36504 W45WQ 16 norm150ptone',
#  'guaranteed 200 award even 1000 cashto claim UR award call free 08000407165 18 2 stop getstop 88222 PHP RG21 4JX',
#  'K Ill 4',
#  'dled 3d imp',
#  'sure make sure know aint smokin yet',
#  'Boooo always work quit',
#  'take half day leave bec well',
#  'Ugh dont wan na get bed warm',
#  'Ssnervous ltgt',
#  'there ring come guy costume gift future yowifes Hint hint',
#  'Congratulations ur award either 500 CD gift voucher Free entry 2 100 weekly draw txt MUSIC 87066 TnCs wwwLdewcom1win150ppmx3age16',
#  'borrow ur bag ok',
#  'U outbid simonwatson5120 Shinco DVD Plyr 2 bid visit sm acsmsrewards 2 end bid notification reply END',
#  'Wheres boytoy miss happen',
#  'lot use one babe model doesnt help Youi bring hell match',
#  'Also bring galileo dobby',
#  'respond',
#  'BOO BABE U ENJOYIN YOURJOB U SEEMED 2 B GETTIN WELL HUNNYHOPE URE OKTAKE CARE ILLSPEAK 2U SOONLOTS LOVEME XXXX',
#  'Good afternoon starshine Hows boytoy crave yet Ache fuck sip cappuccino miss babe tease kiss',
#  'road cant txt',
#  'SMSSERVICES yourinclusive text credit pls goto wwwcomuknet login 3qxj9 unsubscribe STOP extra charge help 08702840625COMUK 220CM2 9AE',
#  '25p 4 alfie Moons Children need song ur mob Tell ur m8s Txt Tone charity 8007 Nokias Poly charity polys zed 08701417012 profit 2 charity',
#  'good even Ttyl',
#  'Hmm Bits piece lol sigh',
#  'Hahahause brain dear',
#  'Hey get mail',
#  'Sorry light turn green meant another friend want ltgt worth may around',
#  'Thanks yesterday sir wonderful Hope enjoy burial MojiBiola',
#  'U secret admirer REVEAL think U R special Call 09065174042 opt Reply REVEAL STOP 150 per msg recd Cust care 07821230901',
#  'Hi mate RV u hav nice hol message 3 say hello coz havent sent u 1 age start drive stay roadsRVx',
#  'Dear Voucher Holder claim week offer PC please go httpwwwetlpcoukexpressoffer TsCs apply stop text txt STOP 80062',
#  'Thank much skyped wit kz sura didnt get pleasure company Hope good Weve give ultimatum oh countin aburo Enjoy message sent day ago',
#  'Surely result offer',
#  'Good Morning Dear great amp successful day',
#  'want 750 anytime network min 150 text NEW VIDEO phone five pound per week call 08002888812 reply delivery tomorrow',
#  'Sir late pay rent past month pay ltgt charge felt would inconsiderate nag something give great cost thats didnt speak however recession wont able pay charge month hence askin well ahead month end please help Thanks',
#  'try contact offer New Video Phone 750 anytime network min HALF PRICE Rental camcorder call 08000930705 reply delivery Wed',
#  'Last chance 2 claim ur 150 worth discount vouchersText YES 85023 nowSavaMobmember offer mobile Cs 08717898035 300 Sub 16 Remove txt X STOP',
#  'luv u soo much u dont understand special u r 2 ring u 2morrow luv u xxx',
#  'Pls send comprehensive mail im pay much',
#  'Prashanthettans mother pass away last night pray family',
#  'Urgent call 09066350750 landline complimentary 4 Ibiza Holiday 10000 cash await collection SAE TCs PO BOX 434 SK3 8WP 150 ppm 18',
#  'Kkwhen go',
#  'Meanwhile shit suite xavier decide give u ltgt second warn samantha come play jay guitar impress shit Also dont think doug realizes dont live anymore',
#  'stomach thru much trauma swear cant eat well lose weight',
#  'officewhats mattermsg nowi call break',
#  'Yeah there barely enough room two u x many fuck shoe Sorry man see later',
#  'Todays Offer Claim ur 150 worth discount voucher Text YES 85023 SavaMob member offer mobile Cs 08717898035 300 Sub 16 Unsub reply X',
#  'U reach orchard already U wan 2 go buy ticket first',
#  'real baby want bring inner tigress',
#  'da run activate full version da',
#  'AH POOR BABYHOPE URFEELING BETTERSN LUV PROBTHAT OVERDOSE WORK HEY GO CAREFUL SPK 2 U SN LOTS LOVEJEN XXX',
#  'Stop story Ive told ive return he say order',
#  'Talk sexy Make new friend fall love world discreet text date service text VIP 83110 see could meet',
#  'Going take babe',
#  'Hai ana tomarrow come morning ltDECIMALgt ill sathy go RTO office Reply come home',
#  'Spoons okay',
#  'say somebody name tampa',
#  'work Going min',
#  'brother genius',
#  'Sorry guess whenever get hold connection maybe hour two Ill text',
#  'u find time bus coz need sort stuff',
#  'Dude ive see lotta corvette lately',
#  'Congratulations ur award either yr supply CDs Virgin Records Mystery Gift GUARANTEED Call 09061104283 TsCs wwwsmsconet 150pm approx 3mins',
#  'consider wall bunker shit important never play peaceful guess place high enough dont matter',
#  'PRIVATE 2003 Account Statement 07808 XXXXXX show 800 unredeemed point Call 08719899217 Identifier Code 41685 Expires 071104',
#  'Hello need posh bird chap user trial prod champneys put need address dob asap Ta r',
#  'U want Xmas 100 free text message new video phone half price line rental Call free 0800 0721072 find',
#  'Well officially philosophical hole u wan na call home ready save',
#  'go goodno problembut still need little experience understand american customer voice',
#  'Ill text drop x',
#  'Ugh long day Im exhaust want cuddle take nap',
#  'Talk Atleast Day Otherwise Miss Best FRIEND WORLD Shakespeare SHESIL ltgt',
#  'Shop till u Drop either 10K 5K 500 Cash 100 Travel voucher Call 09064011000 NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary',
#  'castor need see something',
#  'Sunshine Quiz Wkly Q Win top Sony DVD player u know country Liverpool played mid week Txt ansr 82277 150 SPTyrone',
#  'U secret admirer look 2 make contact Ufind Rreveal think UR specialcall 09058094565',
#  'U Secret Admirer look 2 make contact Ufind Rreveal think UR specialcall 09065171142stopsms08',
#  'Reminder download content already paid Goto httpdoit mymoby tv collect content',
#  'see knew give break time woul lead always want miss curfew gon na gibe til one MIDNIGHT movie gon na get til 2 need come home need getsleep anything need b studdying ear training',
#  'love give massage use lot baby oil fave position',
#  'Dude go sup',
#  'Yoyyooo u know change permission drive mac usb flash drive',
#  'Gibbs unsoldmike hussey',
#  'like talk pa able dont know',
#  'dun cut short leh U dun like ah fail Shes quite sad',
#  'unbelievable faglord',
#  'Wifehow knew time murder exactly',
#  'ask princess',
#  'great princess think',
#  'Nutter Cutter Ctter Cttergg Cttargg Ctargg Ctagg ie',
#  'ok noe ure busy im really bore msg u oso dunno wat colour choose 4 one',
#  'Doesnt g class early tomorrow thus shouldnt try smoke ltgt',
#  'Superb Thought grateful u dont everything u want mean u still opportunity happier tomorrow u today',
#  'Hope good week check',
#  'Im use hope agent dont drop since ive book thing year whole boston nyc experiment',
#  'Thursday night Yeah sure thing well work',
#  'free ringtone wait collect Simply text password MIX 85069 verify Get Usher Britney FML PO Box 5249 MK17 92H 450Ppw 16',
#  'Probably money worry Things come due several outstanding invoice work two three month ago',
#  'possible teach',
#  'wonder phone battery go dead tell love babe',
#  'Lovely smell bus aint tobacco',
#  'get worried derek taylor already assume bad',
#  'Hey whats charles sorry late reply',
#  'last Stereophonics Marley Dizzee Racal Libertines Strokes Win Nookii game Flirt Click TheMob WAP Bookmark text WAP 82468',
#  'Ill give Plus say grinule greet whenever speak',
#  'WHITE FUDGE OREOS STORES',
#  'January Male Sale Hot Gay chat cheaper call 08709222922 National rate 15pmin cheap 78pmin peak stop text call 08712460324 10pmin',
#  'love come take long leave Zahers get word ym happy see sad left miss',
#  'sorry hurt',
#  'Cant feel nauseous Im piss didnt eat sweet week cause today planning pig diet week Im hungry',
#  'Ok lor early still project meeting',
#  'Call da wait call',
#  'could ask carlos could get anybody else chip',
#  'actually send reminder today wonderful weekend',
#  'people see msg think Iam addict msging wrong Bcoz dont know Iam addict sweet Friends BSLVYL',
#  'Hey give photo register drive ah Tmr wan na meet yck',
#  'Dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashleys number',
#  'shall fine avalarr hollalater',
#  'go attend another two round todaybut still didt reach home',
#  'Actually delete old websitenow blogging magicalsongsblogspotcom',
#  'K wait chikkuil send aftr ltgt min',
#  'Im diet ate 1 many slice pizza yesterday Ugh Im ALWAYS diet',
#  'Ki give kvb acc detail',
#  'Oh come ah',
#  'money r lucky winner 2 claim prize text money 2 88600 1million give away ppt150x3normal text rate box403 w1t1jy',
#  'Im really sorry wont b able 2 fridayhope u find alternativehope yr term go ok',
#  'Congratulations ore mo owo wa Enjoy wish many happy moment fro wherever go',
#  'samus shoulder yet',
#  'time think youll Need know near campus',
#  'Dear Matthew please call 09063440451 landline complimentary 4Lux Tenerife holiday 1000 CASH await collection ppm150 SAE TCs Box334 SK38XH',
#  'dun wear jean lor',
#  'Since side fever vomitin',
#  'Kkare college',
#  'Urgent call 09061749602 Landline complimentary 4 Tenerife Holiday 10000 cash await collection SAE TCs BOX 528 HP20 1YF 150ppm 18',
#  'Better Made Friday stuffed like pig yesterday feel bleh least writhe pain kind bleh',
#  'sell well ton coin sell coin someone thru paypal Voila Money back life pocket',
#  'Theyre lot place hospital medical place safe',
#  'get touch folk wait company txt back NAME AGE opt Enjoy community 150pSMS',
#  'also Ive sorta blown couple time recently id rather text blue look weed',
#  'sent score sophas secondary application school think think apply research cost also Contact joke ogunrinde school one less expensive one',
#  'cant wait see photo useful',
#  'Ur cashbalance currently 500 pound maximize ur cashin send GO 86688 150pmsg CC 08718720201 PO BOX 11414 TCRW1',
#  'Hey book kb sat already lesson go ah Keep sat night free need meet confirm lodge',
#  'Chk ur belovd m dict',
#  'time want come',
#  'Awesome lem know whenever youre around',
#  'Shb b ok lor Thanx',
#  'Beautiful Truth Gravity Read carefully heart feel light someone feel heavy someone leaf GOOD NIGHT',
#  'Also remember get dobbys bowl car',
#  'Filthy story GIRLS wait',
#  'Sorry c ur msg Yar lor poor thing 4 one night Tmr ull brand new room 2 sleep',
#  'Love isnt decision feel could decide love life would much simpler less magical',
#  'Welp apparently retire',
#  'sort code acc bank natwest reply confirm ive sent right person',
#  '',
#  'U sure u cant take sick time',
#  'URGENT try contact U Todays draw show 800 prize GUARANTEED Call 09050001808 land line Claim M95 Valid12hrs',
#  'Watching cartoon listen music amp eve go temple amp church u',
#  'Yo chad gymnastics class wan na take site say Christians class full',
#  'much buzy',
#  'well still catch let ask sell ltgt',
#  'sure night menu know noon menu',
#  'u want come backa beautiful necklace token heart youthats give WIFE LIKINGBE SEENO ONE give thatdont call mei wait till come',
#  'willing go aptitude class',
#  'wont b 215 try 2 sort house ok',
#  'Yar lor wan 2 go c horse race today mah eat earlier lor ate chicken rice U',
#  'Haha awesome omw back',
#  'Yup thk e shop close lor',
#  'account number',
#  'Eh u send wrongly lar',
#  'Hey ad crap nite borin without ya 2 boggy u boring biatch Thanx u wait til nxt time il ave ya',
#  'Ok shall talk',
#  'Dont hesitate know second time weakness like keep notebook eat day anything change day sure nothing',
#  'Hey pay salary de ltgt',
#  'Another month need chocolate weed alcohol',
#  'start search get job dayshe great potential talent',
#  'Reckon need town eightish walk carpark',
#  'Congrats 2 mobile 3G Videophones R call 09063458130 videochat wid mate play java game Dload polyPH music noline rentl',
#  'LOOK FUCKIN TIME FUCK THINK',
#  'Yo guess drop',
#  'Carlos say hell mu ltgt minute',
#  'Im office call ltgt min',
#  'Geeee miss already know think Fuck cant wait till next year together love kiss',
#  'Yun ahthe ubi one say wan call tomorrowcall 67441233 look ireneere get bus822656166382 Ubi cresubi tech park6ph 1st 5wkg daysn',
#  'Ugh Got ta drive back sd la butt sore',
#  '26th JULY',
#  'Hi im relax time ever get 7am every day party good night get home tomorrow 5ish',
#  'wan come come lor din c stripe skirt',
#  'Xmas story peace Xmas msg love Xmas miracle jesus Hav bless month ahead amp wish U Merry Xmas',
#  'cant dont number',
#  'Change e one next escalator',
#  'Yetunde im class run water make ok Pls',
#  'lot happen Feels quiet Beth aunt charlie work lot helen mo',
#  'wait 4 bus stop aft ur lect lar dun c go get car come back n pick',
#  ...]

# %%
from sklearn.cross_validation import train_test_split

x_train, x_test, y_train, y_test = train_test_split(clean_text, target, test_size = 0.2, random_state = 42)
count_vec = CountVectorizer(analyzer = "word", max_features = 4500, ngram_range = (1, 2))

train_transformed = count_vec.fit_transform(x_train)
test_transformed = count_vec.transform(x_test)
# Out:
# C:\Users\dhruv\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(train_transformed, y_train)
clf.score(test_transformed, y_test)
# Out:
# 0.98026905829596411

# %%
import pickle
save_classifier = open("EmailSpam_MNB.pickle", "wb")
pickle.dump(clf, save_classifier)
save_classifier.close()
